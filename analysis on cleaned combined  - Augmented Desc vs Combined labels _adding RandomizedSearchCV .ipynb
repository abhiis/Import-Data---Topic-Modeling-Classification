# %%
import os
from glob import glob as g
import pandas as pd
import numpy as np

# %%
from rake_nltk import Rake
import nltk
#nltk.download('stopwords')
# Initialize RAKE by optionally providing a list of stopwords
rake = Rake()

# %%
mapping_lens = pd.read_csv("X Surg Mapping lens.csv")

# %%
detailed_products = cleaned.to_dict('records')

# %%
for row in detailed_products:
    print("#######")
   
    
    desc = row['Detailed_Product_EN']
    imp = row['Importer']
    exp = row['Exporter']
    identification_soup = "; ".join([desc,imp,exp]) 
    print(identification_soup)
    
    rake.extract_keywords_from_text(identification_soup)

    # Get ranked phrases and scores
    keywords_with_scores = rake.get_ranked_phrases_with_scores()

    # Display the keywords with their scores
    for score, keyword in keywords_with_scores:
        print(f"{keyword}: {score}")
        
    print(row['Keyword Suggested'])
    print()
# Out:
# #######
# dxl 800 pm modified asp probe kit for analyzer equipment; PROMOCION MEDICA S A; BECKMAN COULTER
# dxl 800 pm modified asp probe kit: 49.0
# promocion medica: 4.0
# beckman coulter: 4.0
# analyzer equipment: 4.0
#  kit
#
# #######
# guide wire; DROGUERIA RAMON GONZALEZ REVILLA S A; ABBOTT
# drogueria ramon gonzalez revilla: 16.0
# guide wire: 4.0
# abbott: 1.0
# guide wire
#
# #######
# endotracheal tubes; KENDALL S A; MEDTRONIC
# endotracheal tubes: 4.0
# medtronic: 1.0
# kendall: 1.0
# endotracheal tube
#
# #######
# endotracheal tubes; KENDALL S A; MEDTRONIC
# endotracheal tubes: 4.0
# medtronic: 1.0
# kendall: 1.0
# endotracheal tube
#
# #######
# glucose meter 5975976731; DHL PANAMA S A; DHL AIRWAYS
# glucose meter 5975976731: 9.0
# dhl panama: 4.0
# dhl airways: 4.0
# glucose
#
# #######
# endotracheal tubes; KENDALL S A; MEDTRONIC
# endotracheal tubes: 4.0
# medtronic: 1.0
# kendall: 1.0
# endotracheal tube
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ETHNOR DEL ISTMO
# ethnor del istmo: 9.0
# surgical instruments: 4.0
# orto sistemas: 4.0
# surgical instrument
#
# #######
# sensor for insulin pump system (parts); KENDALL S A; MEDTRONIC
# parts ); kendall: 9.0
# insulin pump system: 9.0
# sensor: 1.0
# medtronic: 1.0
# sensor for insulin pump system
#
# #######
# surgical instruments; PROMOCION MEDICA S A; HANGZHOU KANGJI MEDICAL INSTRUMENT CO, LTD
# hangzhou kangji medical instrument co: 25.0
# surgical instruments: 4.0
# promocion medica: 4.0
# ltd: 1.0
# surgical instrument
#
# #######
# medical electrodes; PROMOCION MEDICA S A; HANGZHOU KANGJI MEDICAL INSTRUMENT CO, LTD
# hangzhou kangji medical instrument co: 23.5
# medical electrodes: 5.5
# promocion medica: 4.0
# ltd: 1.0
# electrode
#
# #######
# cardiac prosthesis; DROGUERIA RAMON GONZALEZ REVILLA S A; ABBOTT VASCULAR NETHERLANDS BV
# drogueria ramon gonzalez revilla: 16.0
# abbott vascular netherlands bv: 16.0
# cardiac prosthesis: 4.0
# cardiac prosthesis
#
# #######
# skin stapler; LATIN AMERICAN MANAGERS ASSOCIATE INC; DEROYAL/ANSELL
# latin american managers associate inc: 25.0
# skin stapler: 4.0
# deroyal: 1.0
# ansell: 1.0
# skin stapler
#
# #######
# endoscopic ultrasound equipment and accessories; PROMOCION MEDICA S A; SONOSCAPE
# endoscopic ultrasound equipment: 9.0
# promocion medica: 4.0
# sonoscape: 1.0
# accessories: 1.0
# endoscopic
#
# #######
# implants for spine surgery; NEURO DYNAMICS  S A; SPINEWAY
# spine surgery: 4.0
# neuro dynamics: 4.0
# spineway: 1.0
# implants: 1.0
# implants
#
# #######
# medical sensor; KENDALL S A; MEDTRONIC
# medical sensor: 4.0
# medtronic: 1.0
# kendall: 1.0
# medical sensor
#
# #######
# glucose control system; BIO LAB INTERNACIONAL,S.A.; ABBOTT
# glucose control system: 9.0
# bio lab internacional: 9.0
# abbott: 1.0
# glucose
#
# #######
# guide; DROGUERIA RAMON GONZALEZ REVILLA S A; MARKET SECURITY INC
# drogueria ramon gonzalez revilla: 16.0
# market security inc: 9.0
# guide: 1.0
# guide
#
# #######
# oxygenator with filter 17 un r-1 and r-2 30 un o/c. 1000914872-08-107; CAJA DE SEGURO SOCIAL; MARKET SECURITY INC
# caja de seguro social: 16.0
# filter 17 un r: 14.0
# 2 30 un: 9.5
# market security inc: 9.0
# r: 2.5
# oxygenator: 1.0
# c: 1.0
# 107: 1.0
# 1000914872: 1.0
# 1: 1.0
# 08: 1.0
# oxygenator
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# diagnostic catheter; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# diagnostic catheter: 4.0
# diagnostic catheter
#
# #######
# cannulas and similar instruments; IMPORTACIONES NEMMESIS S A; pajunk
# similar instruments: 4.0
# importaciones nemmesis: 4.0
# pajunk: 1.0
# cannulas: 1.0
# cannulas and similar instrument
#
# #######
# surgical sutures; OPM MEDICAL INC; TAGUMEDICA S.A.
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# suture
#
# #######
# surgical sutures of monofilament nylon, polyglycolic acid, braided silk, chromic catgut, simple catgut.; INTERMEDIC S.A.; UNILENE
# surgical sutures: 4.0
# simple catgut: 4.0
# polyglycolic acid: 4.0
# monofilament nylon: 4.0
# chromic catgut: 4.0
# braided silk: 4.0
# .; unilene: 4.0
# intermedic: 1.0
# nylon
#
# #######
# coronary balloon fact. 1628; PROMOCION MEDICA S A; BOSTON SCIENTIFIC INTL. B.V.
# coronary balloon fact: 9.0
# boston scientific intl: 9.0
# promocion medica: 4.0
# v: 1.0
# b: 1.0
# 1628: 1.0
# coronary balloon
#
# #######
# monitoring electrode; MEDI SOLUTIONS INC; SHANGHAI KINMED IMPORT & EXPORT CO., LTD.
# export co ., ltd: 16.0
# shanghai kinmed import: 9.0
# medi solutions inc: 9.0
# monitoring electrode: 4.0
# electrode
#
# #######
# medical sensor; KENDALL S A; MEDTRONIC
# medical sensor: 4.0
# medtronic: 1.0
# kendall: 1.0
# medical sensor
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# implants: ultrapure collagen matrix graft (r-1 partial delivery 5 units, r-2 complete delivery 5 units and r-3 partial delivery 4 units 14 units); CAJA DE SEGURO SOCIAL; INTEGRA LIFESCIENCES SALES LLC
# 3 partial delivery 4 units 14 units ); caja de seguro social: 128.83333333333331
# 1 partial delivery 5 units: 34.33333333333333
# 2 complete delivery 5 units: 30.833333333333332
# ultrapure collagen matrix graft: 16.0
# integra lifesciences sales llc: 16.0
# r: 1.0
# r: 1.0
# r: 1.0
# implants: 1.0
# collagen matrix
#
# #######
# hemostatic seals; FP LATAM S.A; BIOLIFE LLC
# hemostatic seals: 4.0
# fp latam: 4.0
# biolife llc: 4.0
# hemostatic seal
#
# #######
# endoscopy capsule; CEDI MEDICAL PANAMA, S.A.; INTROMEDIC CO., LTD
# .; intromedic co ., ltd: 25.0
# cedi medical panama: 9.0
# endoscopy capsule: 4.0
# endoscopy capsule
#
# #######
# surgical instruments; INNOMED PANAMA S.A.; NOUVAG AG
#
# #######
# endotracheal tubes; KENDALL S A; MEDTRONIC
# endotracheal tubes: 4.0
# medtronic: 1.0
# kendall: 1.0
# endotracheal tube
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# spo2 finger sensor; DRAEGER PANAMA COMERCIAL S; DRAEGERWEERK AG & CO
# spo2 finger sensor: 9.0
# draeger panama comercial: 9.0
# draegerweerk ag: 4.0
# co: 1.0
# spo2 finger sensor
#
# #######
# electrodes for medical use; PROMOCION MEDICA S A; NATUS NEUROLOGY INCORPORATED
# natus neurology incorporated: 9.0
# promocion medica: 4.0
# medical use: 4.0
# electrodes: 1.0
# electrode
#
# #######
# hemostatic seals; FP LATAM S.A; BIOLIFE LLC
# hemostatic seals: 4.0
# fp latam: 4.0
# biolife llc: 4.0
# hemostatic seal
#
# #######
# surgical sutures; OPM MEDICAL INC; TAGUMEDICA S A
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# suture
#
# #######
# thermal blankets; MEDICAL DEPOT S A; 3M,RMC,CARDINAL HEALTH,BUSSE,HILLROM,DORIAN DRAKE,ADC,
# thermal blankets: 4.0
# medical depot: 4.0
# dorian drake: 4.0
# cardinal health: 4.0
# rmc: 1.0
# hillrom: 1.0
# busse: 1.0
# adc: 1.0
# 3m: 1.0
# thermal blanket
#
# #######
# tracheostomy set; MEDICAL DEPOT S A; 3M,RMC,CARDINAL HEALTH,BUSSE,HILLROM,DORIAN DRAKE,ADC,
# tracheostomy set: 4.0
# medical depot: 4.0
# dorian drake: 4.0
# cardinal health: 4.0
# rmc: 1.0
# hillrom: 1.0
# busse: 1.0
# adc: 1.0
# 3m: 1.0
# tracheostomy
#
# #######
# acurate tf transfemoral aortic valve system; PROMOCION MEDICA S A; PROMOCION MEDICA  DE EL SALVADOR SA DE CV
# promocion medica de el salvador sa de cv: 58.0
# acurate tf transfemoral aortic valve system: 36.0
# promocion medica: 10.0
# valve
#
# #######
# acurate tf transfemoral aortic valve system; PROMOCION MEDICA S A; PROMOCION MEDICA  DE EL SALVADOR SA DE CV
# promocion medica de el salvador sa de cv: 58.0
# acurate tf transfemoral aortic valve system: 36.0
# promocion medica: 10.0
# valve
#
# #######
# coronary stenting; STAR MEDICS S A; BONAVIX S.A
# star medics: 4.0
# coronary stenting: 4.0
# bonavix: 1.0
# coronary stenting
#
# #######
# 901890900090 disposable cannulas for laparoscopic surgery lina maxflow 5mm 5mm probe extended length (370mm) for linamaxflow single use; MEDI FAST  S A; LINA MEDICAL INTERNATIONAL OPERATIONS AG
# laparoscopic surgery lina maxflow 5mm 5mm probe extended length: 79.0
# lina medical international operations ag: 27.0
# linamaxflow single use: 9.0
# 901890900090 disposable cannulas: 9.0
# medi fast: 4.0
# 370mm: 1.0
# maxflow
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# absorbable hemostatic; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# absorbable hemostatic: 4.0
# absorbable hemostatic
#
# #######
# hospital equipment; CAJA DE SEGURO SOCIAL; RICHARD WOLF GMBH
# caja de seguro social: 16.0
# richard wolf gmbh: 9.0
# hospital equipment: 4.0
# hospital equipment
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# absorbable hemostatic; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
DROGUERIA RAMON GONZALEZ REVILLA S A; MARKET SECURITY INC
# drogueria ramon gonzalez revilla: 16.0
# market security inc: 9.0
# oxygenator: 1.0
# oxygenator
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# nitinol hydraulic guides for endovascular procedures o/c 1000908377-08-31/3000401272; CAJA DE SEGURO SOCIAL; TERUMO LATIN AMERICA CORP.
# terumo latin america corp: 16.0
# caja de seguro social: 16.0
# nitinol hydraulic guides: 9.0
# endovascular procedures: 4.0
# c 1000908377: 4.0
# 31: 1.0
# 3000401272: 1.0
# 08: 1.0
# nitinol hydraulic guides for endovascular procedures o/c 1000908377-08-31/3000401272
#
# #######
# hydraulic guides for endovascular procedures; DROGUERIA RAMON GONZALEZ REVILLA S A; TERUMO LATIN AMERICA CORP.
# terumo latin america corp: 16.0
# drogueria ramon gonzalez revilla: 16.0
# hydraulic guides: 4.0
# endovascular procedures: 4.0
# guide
#
# #######
# angle guide; DROGUERIA RAMON GONZALEZ REVILLA S A; MARKET SECURITY INC
# drogueria ramon gonzalez revilla: 16.0
# market security inc: 9.0
# angle guide: 4.0
# guide
#
# #######
# diagnostic catheter; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# diagnostic catheter: 4.0
# diagnostic catheter
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# implantable with its parts and accessories; TECHNOMEDICAL DE PANAMA S A; BIOTRONIK SE & CO
# technomedical de panama: 9.0
# biotronik se: 4.0
# parts: 1.0
# implantable: 1.0
# co: 1.0
# accessories: 1.0
# implantable with its parts and accessories
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# medical electrodes; PROMOCION MEDICA S A; PROMOCION MEDICA  SA (COSTA RICA)
# promocion medica sa: 8.0
# promocion medica: 5.0
# medical electrodes: 4.0
# costa rica: 4.0
# electrode
#
# #######
# hemostatic seals; FP LATAM S.A; BIOLIFE LLC
# hemostatic seals: 4.0
# fp latam: 4.0
# biolife llc: 4.0
# hemostatic seal
#
# #######
# laryngeal mask for respiratory tract for medical use; U S PHARMACY SYSTEMS INC; FLEXICARE MEDICAL LIMITED
# pharmacy systems inc: 9.0
# flexicare medical limited: 8.5
# medical use: 4.5
# respiratory tract: 4.0
# laryngeal mask: 4.0
# u: 1.0
# laryngeal mask for respiratory tract
#
# #######
# endotracheal tube for medical use; U S PHARMACY SYSTEMS INC; FLEXICARE MEDICAL LIMITED
# pharmacy systems inc: 9.0
# flexicare medical limited: 8.5
# medical use: 4.5
# endotracheal tube: 4.0
# u: 1.0
# endotracheal tube
#
# #######
# demineralized bone matrix ballast in reabsorbable mesh; VITALMEDIC S A; ISO TIS ORTHO BIOLOGI
# iso tis ortho biologi: 16.0
# demineralized bone matrix ballast: 16.0
# reabsorbable mesh: 4.0
# vitalmedic: 1.0
# demineralized
#
# #######
# oxygen sensor for pediatric use 5152798033; DHL PANAMA S A; DHL AIRWAYS
# pediatric use 5152798033: 9.0
# oxygen sensor: 4.0
# dhl panama: 4.0
# dhl airways: 4.0
# sensor
#
# #######
# oxygen sensor 4434546981; DHL PANAMA S A; dhl airways
# oxygen sensor 4434546981: 9.0
# dhl panama: 4.0
# dhl airways: 4.0
# sensor
#
# #######
#
# #######
# catheters; PROMOCION MEDICA S A; BOSTON SCIENTIFIC INTERNATIONAL BV
# boston scientific international bv: 16.0
# promocion medica: 4.0
# catheters: 1.0
# catheters
#
# #######
# surgical instruments; DISTRICLINIC PANAMA, S.A.; ZHEJIANG GEYI MEDICAL INSTRUMENT CO., LTD
# .; zhejiang geyi medical instrument co ., ltd: 64.0
# surgical instruments: 4.0
# districlinic panama: 4.0
# surgical instrument
#
# #######
# complete laryngeal mask for respiratory tract with its parts and accessories for medical use; U S PHARMACY SYSTEMS INC; FLEXICARE INC.
# complete laryngeal mask: 9.0
# pharmacy systems inc: 8.5
# flexicare inc: 4.5
# respiratory tract: 4.0
# medical use: 4.0
# u: 1.0
# parts: 1.0
# accessories: 1.0
# laryngeal mask for respiratory tract
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# adult/pediatric spo2 sensor; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# pediatric spo2 sensor: 9.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# adult: 1.0
# spo2 sensor
#
# #######
# surgical instrument (shaver for arthroscopy); PROMOCION MEDICA S A; LIDERMED, S.A.
# arthroscopy ); promocion medica: 16.0
# surgical instrument: 4.0
# shaver: 1.0
# lidermed: 1.0
# surgical instrument
#
# #######
# catheters; PROMOCION MEDICA S A; BOSTON SCIENTIFIC CORPORATION
# boston scientific corporation: 9.0
# promocion medica: 4.0
# catheters: 1.0
# catheters
#
# #######
# soft tip spo2 sensor; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# soft tip spo2 sensor: 16.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# spo2 sensor
#
# #######
# spo2 finger sensors; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# spo2 finger sensors: 9.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# spo2 finger sensor
#
# #######
# 1zw485w20492191065-surgical medical instruments; UPS FREIGHT SERVICES PANAMA INC; UPS CONSOLIDATE
# ups freight services panama inc: 23.5
# surgical medical instruments: 9.0
# ups consolidate: 5.5
# 1zw485w20492191065: 1.0
# surgical medical instrument
#
# #######
# neonate spo2 sensor; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# neonate spo2 sensor: 9.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# spo2 sensor
#
# #######
# oxygen sensor 3349959314; DHL PANAMA S A; DHL AIRWAYS
# oxygen sensor 3349959314: 9.0
# dhl panama: 4.0
# dhl airways: 4.0
# sensor
#
# #######
# catheters; PROMOCION MEDICA S A; BOSTON SCIENTIFIC CORPORATION
# boston scientific corporation: 9.0
# promocion medica: 4.0
# catheters: 1.0
# catheters
#
# #######
# thermal blankets; MEDICAL DEPOT S A; 3M,RMC.CARDINAL HEALTH
# thermal blankets: 4.0
# medical depot: 4.0
# cardinal health: 4.0
# rmc: 1.0
# 3m: 1.0
# thermal blanket
#
# #######
# cannulas and similar instruments; IMPORTACIONES NEMMESIS S A; PAJUNK
# similar instruments: 4.0
# importaciones nemmesis: 4.0
# pajunk: 1.0
# cannulas: 1.0
# cannulas and similar instrument
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# absorbable hemostatic; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# absorbable hemostatic: 4.0
# absorbable hemostatic
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# tracheostomy tray; MEDICAL DEPOT S A; 3M,DORIAN DRAKE,CARDINAL HEALTH,BUSSE,HILLROM
# tracheostomy tray: 4.0
# medical depot: 4.0
# dorian drake: 4.0
# cardinal health: 4.0
# hillrom: 1.0
# busse: 1.0
# 3m: 1.0
# tracheostomy
#
# #######
# oxygen sensor cif freight 100.00 s 9033672152; DHL PANAMA S A; DHL AIRWAYS
# oxygen sensor cif freight 100: 25.0
# dhl panama: 4.0
# dhl airways: 4.0
# 9033672152: 1.0
# 00: 1.0
# sensor
#
# #######
# surgical sutures; OPM MEDICAL INC; TEGUMEDICA S A
# opm medical inc: 9.0
# surgical sutures: 4.0
# tegumedica: 1.0
# suture
#
# #######
# pulse oximeter; FRED SERHAL NAKAD; AMAZON
# fred serhal nakad: 9.0
# pulse oximeter: 4.0
# amazon: 1.0
# pulse oximeter
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A; ARTHREX
# surgical instruments: 4.0
# orto sistemas: 4.0
# arthrex: 1.0
# surgical instrument
#
# #######
# surgical medical instruments; MEDICAL INNOVATIONS ADVANCES CORP; RZ MEDIZINTECHNK
# medical innovations advances corp: 15.5
# surgical medical instruments: 9.5
# rz medizintechnk: 4.0
# surgical medical instrument
#
# #######
# surgical medical instruments; TAMIR S A; NOPA INSTRUMENTS
# surgical medical instruments: 8.5
# nopa instruments: 4.5
# tamir: 1.0
# surgical medical instrument
#
# #######
# implantable with its parts and accessories; TECHNOMEDICAL DE PANAMA S A ; BIOTRONIK
# technomedical de panama: 9.0
# parts: 1.0
# implantable: 1.0
# biotronik: 1.0
# accessories: 1.0
# implantable with its parts and accessories
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# oxygenator; DROGUERIA RAMON GONZALEZ REVILLA S A; MARKET SECURITY INC
# drogueria ramon gonzalez revilla: 16.0
# market security inc: 9.0
# oxygenator: 1.0
# oxygenator
#
# #######
# implantable with its parts and accessories; TECHNOMEDICAL DE PANAMA S A ; BIOTRONIK
# technomedical de panama: 9.0
# parts: 1.0
# implantable: 1.0
# biotronik: 1.0
# accessories: 1.0
# implantable with its parts and accessories
#
# #######
# surgical instrument; ETHNOR DEL ISTMO S A; ETHNOR DEL ISTMO S A
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# surgical instrument: 4.0
# surgical instrument
#
# #######
# ventstar anesthesia set; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# ventstar anesthesia set: 9.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# ventstar
#
# #######
# ventstar breathing circuits; DRAEGER PANAMA COMERCIAL S; DRAEGERWERK AG & CO
# ventstar breathing circuits: 9.0
# draeger panama comercial: 9.0
# draegerwerk ag: 4.0
# co: 1.0
# ventstar
#
# #######
# hydrophilic nitinol guides o/c 1000900666-06-01 lot: 221215 - 80 units; CAJA DE SEGURO SOCIAL; MARKET SECURITY INC
# caja de seguro social: 16.0
# market security inc: 9.0
# hydrophilic nitinol guides: 9.0
# c 1000900666: 4.0
# 80 units: 4.0
# 01 lot: 4.0
# 221215: 1.0
# 06: 1.0
# nitinol guide
#
# #######
# argon ekm inflation device; CORPORACION BIOMUR  S A; ARGON MEDICAL DEVICES INC
# argon medical devices inc: 16.0
# argon ekm inflation device: 16.0
# corporacion biomur: 4.0
# argon ekm inflation device
#
# #######
# sensor for vital signs monitor; IMPORT MEDICAL S A; MASIMO
# vital signs monitor: 9.0
# import medical: 4.0
# sensor: 1.0
# masimo: 1.0
# sensor for vital
#
# #######
# vital sign monitor; IMPORT MEDICAL S A; MASIMO
# vital sign monitor: 9.0
# import medical: 4.0
# masimo: 1.0
# vital sign monitor
#
# #######
# cannulas and similar instruments; IMPORTACIONES NEMMESIS S A; pajunk
# similar instruments: 4.0
# importaciones nemmesis: 4.0
# pajunk: 1.0
# cannulas: 1.0
# cannulas and similar instrument
#
# #######
# surgical instruments; ORTO SISTEMAS  S  A;
0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; polysuture industria e comercio ltda
# polysuture industria e comercio ltda: 25.0
# sutures: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; polysuture industria e comercio ltda
# polysuture industria e comercio ltda: 25.0
# sutures: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; kendall s a; medtronic
# sutures: 1.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# surgical sutures; kendall s a; medtronic
# surgical sutures: 4.0
# medtronic: 1.0
# kendall: 1.0
# suture
#
# #######
# sutures; ethnor del istmo s a; ethnor del istmo s a
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# sutures: 1.0
# suture
#
# #######
# sutures; ethnor del istmo s a; ethnor del istmo s a
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# sutures: 1.0
# suture
#
# #######
# sutures; ethnor del istmo s a; ethnor del istmo s a
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# sutures: 1.0
# suture
#
# #######
# sutures; ethnor del istmo s a; ethnor del istmo s a
# ethnor del istmo: 9.0
# ethnor del istmo: 9.0
# sutures: 1.0
# suture
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# medical sutures 8168 3091 6672 e 1; federal express corporation; fedex
# medical sutures 8168 3091 6672 e 1: 49.0
# federal express corporation: 9.0
# fedex: 1.0
# 8168 3091 6672 e 1
#
# #######
# sutures for students pan9092583219 pty165164; airbox express s.a.; varios suplidores
# students pan9092583219 pty165164: 9.0
# .; varios suplidores: 9.0
# airbox express: 4.0
# sutures: 1.0
# pty165164
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; pty medical group s.a; surgical specialties corporations
# pty medical group: 9.0
# surgical specialties corporations: 8.5
# surgical sutures: 4.5
# suture
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; oriana osiris ortiz castillo de wittgreen; mr innovation co ltd
# oriana osiris ortiz castillo de wittgreen: 36.0
# mr innovation co ltd: 16.0
# surgical sutures: 4.0
# sutures
#
# #######
# surgical sutures; b  medic industries international  s a; shandong deneb international co.,ltd
# shandong deneb international co ., ltd: 35.0
# b medic industries international: 17.0
# surgical sutures: 4.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica s, a
# opm medical inc: 9.0
# surgical sutures: 4.0
# tagumedica: 1.0
# sutures
#
# #######
# surgical sutures; opm medical inc; tagumedica sa
# opm medical inc: 9.0
# tagumedica sa: 4.0
# surgical sutures: 4.0
# sutures
#
# #######
# surgical sutures - polypropylene surgical sutures - nylon monofilament surgical sutures - polyglycolic acid surgical sutures - braided silk surgical sutures - chromic catgut; intermedic s.a.; unilene
# polyglycolic acid surgical sutures: 14.8
# nylon monofilament surgical sutures: 14.8
# braided silk surgical sutures: 14.8
# polypropylene surgical sutures: 9.8
# surgical sutures: 6.8
# chromic catgut: 4.0
# .; unilene: 4.0
# intermedic: 1.0
# polypropylene
#
# #######
# medical adhesive sutures; solis import s a; adhezion biomedical
# medical adhesive sutures: 9.0
# solis import: 4.0
# adhezion biomedical: 4.0
# adhesive
#
# #######
# medical adhesive sutures; solis import s a; adhezion biomedical
# medical adhesive sutures: 9.0
# solis import: 4.0
# adhezion biomedical: 4.0
# adhesive
#
# #######
# medical sutures; solis import s a; adhezion biomedical, llc
# solis import: 4.0
# medical sutures: 4.0
# adhezion biomedical: 4.0
# llc: 1.0
# suture
#
# #######
# surgical sutures; solis import s a; atramat
# surgical sutures: 4.0
# solis import: 4.0
# atramat: 1.0
# sutures
#
# #######
# surgical sutures; solis import s a; atramat
# surgical sutures: 4.0
# solis import: 4.0
# atramat: 1.0
# sutures
#
# #######
# surgical sutures; solis import s a; atramat
# surgical sutures: 4.0
# solis import: 4.0
# atramat: 1.0
# sutures
#
# #######
# surgical sutures; solis import s a; atramat
# surgical sutures: 4.0
# solis import: 4.0
# atramat: 1.0
# sutures
#
# #######
# surgical sutures- polypropylene surgical sutures- chromic catgut surgical sutures- polyglycolic acid surgical sutures- nylon monofilament; intermedic s.a.; unilene s.a.c
# polyglycolic acid surgical sutures: 14.5
# chromic catgut surgical sutures: 14.5
# polypropylene surgical sutures: 9.5
# surgical sutures: 6.5
# nylon monofilament: 4.0
# .; unilene: 4.0
# intermedic: 1.0
# c: 1.0
# polyglycholic acid silk braided
#
# #######
# surgical sutures of polypropylene, chromic catgut, nylon monofilament, polyglycholic acid silk braided; intermedic s.a.; unilene s.a.c.
# polyglycholic acid silk braided: 16.0
# surgical sutures: 4.0
# nylon monofilament: 4.0
# chromic catgut: 4.0
# .; unilene: 4.0
# polypropylene: 1.0
# intermedic: 1.0
# c: 1.0
# polyglycholic acid silk braided
#
# #######
# surgical sutures; b  medic industries international  s a; unilene s.a.c.
# b medic industries international: 16.0
# surgical sutures: 4.0
# unilene: 1.0
# c: 1.0
# sutures
#
# #######
# surgical sutures - nylon monofilament surgical sutures - polyglycolic acid surgical sutures - braided silk surgical sutures - chromic catgut; intermedic s.a.; unilene sac
# polyglycolic acid surgical sutures: 15.0
# nylon monofilament surgical sutures: 15.0
# braided silk surgical sutures: 15.0
# .; unilene sac: 9.0
# surgical sutures: 7.0
# chromic catgut: 4.0
# intermedic: 1.0
# nylon
#
# #######
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
#       6 imp = row['Importer']
#       7 exp = row['Exporter']
# ----> 8 identification_soup = "; ".join([desc,imp,exp])
#       9 print(identification_soup)
#      11 rake.extract_keywords_from_text(identification_soup)
#
# TypeError: sequence item 1: expected str instance, float found

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.model_selection import GridSearchCV

for col in mapping_lens.columns:
    mapping_lens[col] = mapping_lens[col].astype(str)

# Pass through 'keyword_present' without any transformation
pass_through_transformer = FunctionTransformer(lambda x: x, validate=False)


targets = ['Operating Unit', 'Sub-Operating Unit', 'Product Type', 'Company','Family name']
#Combine categorization columns into a single label
mapping_lens['combined_label'] = mapping_lens[targets].apply(lambda x: '>'.join(x), axis=1)

# Feature engineering.
mapping_lens['augmented_description'] = mapping_lens['Detailed_Product_EN'] + ' KEYWORD_TOKEN ' + mapping_lens['Keyword Suggested']
# Creating a binary feature for keyword presence
mapping_lens['keyword_present'] = mapping_lens.apply(lambda x: x['Keyword Suggested'] in x['Detailed_Product_EN'], axis=1).astype(int)

features = [
    'augmented_description',# Use augmented_description instead of Detailed_Product_EN
    'Importer', 
    'Exporter',
    'Python_Mapped_Device', 
    'Python_Mapped_Family_Name', 
    'Python_Mapped_Manufacturer_Name',
    'keyword_present'  # Make sure this is included
]

target = 'combined_label'



def convert_to_string(x):
    # If x is a list or an array with one element, extract the element
    if isinstance(x, (list, np.ndarray)) and len(x) == 1:
        x = x[0]
    
    if isinstance(x, bytes):  # Directly handle bytes objects
        return x.decode('utf-8')
    else:  # Handle everything else as string
        return str(x)

# Define the preprocessing for text columns with custom conversion
# Enhanced text preprocessing pipeline with adjusted TfidfVectorizer parameters
text_preprocessing = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),  # Handle missing values
    ('tfidf', TfidfVectorizer(preprocessor=convert_to_string, 
                              ngram_range=(1, 2),  # Consider both unigrams and bigrams
                              max_df=0.95,  # Ignore terms that appear in more than 95% of the documents
                              min_df=5,  # Ignore terms that appear in less than 5 documents
                              max_features=10000))  # Limit the number of features to 10,000
])

# Define the preprocessing for categorical columns
categorical_preprocessing = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='unknown')),  # Impute with a placeholder
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Combine preprocessing steps
# preprocessor = ColumnTransformer(transformers=[
#     ('text', TfidfVectorizer(), 'augmented_description'),
#     ('cat', OneHotEncoder(handle_unknown='ignore'), ['Importer', 'Exporter', 'Python_Mapped_Device', 'Python_Mapped_Family_Name', 'Python_Mapped_Manufacturer_Name']),
#     ('binary', pass_through_transformer, ['keyword_present'])
# ])
# Combine preprocessing steps
preprocessor = ColumnTransformer(transformers=[
    ('text', text_preprocessing, ['augmented_description']),  # Use text_preprocessing here
    ('cat', categorical_preprocessing, ['Importer', 'Exporter', 'Python_Mapped_Device', 'Python_Mapped_Family_Name', 'Python_Mapped_Manufacturer_Name']),
    ('binary', pass_through_transformer, ['keyword_present'])
])

# Define the model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
])

#Split data
X_train, X_test, y_train, y_test = train_test_split(mapping_lens[features], mapping_lens[target], test_size=0.1, random_state=44)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# Predict on the test set
y_pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8276440962506995

# %%
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter space
param_distributions = {
    'classifier__n_estimators': [100, 200, 300],
    'classifier__max_depth': [None, 10, 20, 30],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4],
}

# Randomized search with cross-validation
random_search = RandomizedSearchCV(model, param_distributions, n_iter=10, cv=3, scoring='accuracy', random_state=33)
random_search.fit(X_train, y_train)

print("Best parameters:", random_search.best_params_)
print("Best cross-validation score:", random_search.best_score_)
# Out:
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 3 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 420, in fit
#     builder.build(self.tree_, X, y, sample_weight)
#   File "sklearn\tree\_tree.pyx", line 131, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 227, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 724, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\tree\_tree.pyx", line 696, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\tree\_utils.pyx", line 37, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 75104256 bytes
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 420, in fit
#     builder.build(self.tree_, X, y, sample_weight)
#   File "sklearn\tree\_tree.pyx", line 131, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 227, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 724, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\tree\_tree.pyx", line 696, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\tree\_utils.pyx", line 37, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 74711040 bytes
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 394, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1863, in __call__
#     return output if self.return_generator else list(output)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\joblib\parallel.py", line 1792, in _get_sequential_output
#     res = func(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 420, in fit
#     builder.build(self.tree_, X, y, sample_weight)
#   File "sklearn\tree\_tree.pyx", line 131, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 227, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\tree\_tree.pyx", line 724, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\tree\_tree.pyx", line 696, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\tree\_utils.pyx", line 37, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 76087296 bytes
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [0.51377745 0.47832307 0.37886422 0.35920881 0.81955589 0.35759159
#         nan 0.6415376  0.52236114 0.51334204]
#   warnings.warn(
# Best parameters: {'classifier__n_estimators': 100, 'classifier__min_samples_split': 10, 'classifier__min_samples_leaf': 1, 'classifier__max_depth': None}
# Best cross-validation score: 0.8195558872924055

# %%
## Fix errors

# %%
from sklearn.metrics import classification_report

# Get unique labels from both y_test and y_pred
unique_labels = np.unique(np.concatenate((y_test, y_pred)))

# Generate a classification report
report = classification_report(y_test, y_pred, labels=unique_labels, target_names=unique_labels.astype(str))
print(report)
# Out:
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                                                                            precision    recall  f1-score   support
#
#                Cardiac Ablation Solutions>Cardiac Ablation Solutions>Conventional Ablation Catheter>Boston Scientific>nan       0.00      0.00      0.00         0
#                              Cardiac Ablation Solutions>Cardiac Ablation Solutions>Conventional Ablation Catheter>nan>nan       1.00      1.00      1.00         1
#                                         Cardiac Ablation Solutions>Cardiac Ablation Solutions>Diagnostic Catheter>J&J>nan       0.92      1.00      0.96        11
#                                      Cardiac Ablation Solutions>Cardiac Ablation Solutions>Long Introducer Sheath>J&J>nan       0.00      0.00      0.00         0
#                                  Coronary & Renal Denervation>Interventional Coronary>Adapter>Abbott Laboratories>Copilot       0.00      0.00      0.00         0
#                                      Coronary & Renal Denervation>Interventional Coronary>Adapter>Abbott Laboratories>nan       0.00      0.00      0.00         1
#                                   Coronary & Renal Denervation>Interventional Coronary>Adapter>Boston Scientific>Watchdog       1.00      1.00      1.00         1
#                                        Coronary & Renal Denervation>Interventional Coronary>Adapter>Boston Scientific>nan       1.00      1.00      1.00         2
#                                    Coronary & Renal Denervation>Interventional Coronary>Adapter>Merit Medical Systems>nan       1.00      1.00      1.00         1
#                    Coronary & Renal Denervation>Interventional Coronary>Adaptor>APT Medical>Braidin Hemostasis Introducer       0.00      0.00      0.00         0
#                                         Coronary & Renal Denervation>Interventional Coronary>Adaptor>Teleflex>Guardian II       1.00      1.00      1.00         1
#                                     Coronary & Renal Denervation>Interventional Coronary>Aspiration + Combined>Terumo>nan       1.00      1.00      1.00         1
#                                 Coronary & Renal Denervation>Interventional Coronary>Aspiration Catheters>Teleflex>Pronto       0.00      0.00      0.00         0
#                                          Coronary & Renal Denervation>Interventional Coronary>BMS>Abbott Laboratories>nan       0.00      0.00      0.00         1
#                                       Coronary & Renal Denervation>Interventional Coronary>Combined>Boston Scientific>nan       1.00      0.80      0.89         5
#                                                  Coronary & Renal Denervation>Interventional Coronary>Combined>Terumo>nan       1.00      1.00      1.00         1
#                                       Coronary & Renal Denervation>Interventional Coronary>DES>Abbott Laboratories>Xience       0.50      0.25      0.33         4
#                                        Coronary & Renal Denervation>Interventional Coronary>DES>Boston Scientific>Synergy       1.00      1.00      1.00         1
#                                            Coronary & Renal Denervation>Interventional Coronary>DES>Boston Scientific>nan       0.86      1.00      0.92         6
#                                    Coronary & Renal Denervation>Interventional Coronary>DES>Cardinal Health>Elunir_assume       0.00      0.00      0.00         0
#                                           Coronary & Renal Denervation>Interventional Coronary>DES>HexaCath>Titan Optimax       0.00      0.00      0.00         1
#                                     Coronary & Renal Denervation>Interventional Coronary>DES>Medtronic>Resolute Integrity       1.00      1.00      1.00         2
#                                                Coronary & Renal Denervation>Interventional Coronary>DES>Translumina>Yukon       1.00      1.00      1.00         1
#                        Coronary & Renal Denervation>Interventional Coronary>Diagnostic Catheter>Boston Scientific>Impulse       0.60      1.00      0.75         3
#                         Coronary & Renal Denervation>Interventional Coronary>Diagnostic Catheter>Cardinal Health>Infiniti       1.00      1.00      1.00         1
#                                       Coronary & Renal Denervation>Interventional Coronary>Diagnostic Catheter>Terumo>nan       0.67      1.00      0.80         2
#                         Coronary & Renal Denervation>Interventional Coronary>Drug Coated Balloons>Boston Scientific>Agent       0.00      0.00      0.00         2
#                           Coronary & Renal Denervation>Interventional Coronary>Drug Coated Balloons>Boston Scientific>nan       1.00      1.00      1.00         6
#                                     Coronary & Renal Denervation>Interventional Coronary>Drug Coated Balloons>Eurocor>nan       0.00      0.00      0.00         2
#                             Coronary & Renal Denervation>Interventional Coronary>Drug Coated Balloons>Ivascular>Essential       0.00      0.00      0.00         1
#                     Coronary & Renal Denervation>Interventional Coronary>Guide Extension Catheters>Teleflex>Guideliner V3       0.00      0.00      0.00         0
#        Coronary & Renal Denervation>Interventional Coronary>Guidewires>Abbott Laboratories>Hi-Torque Balance Middleweight       1.00      1.00      1.00         1
#                       Coronary & Renal Denervation>Interventional Coronary>Guidewires>Abbott Laboratories>Hi-Torque Pilot       1.00      1.00      1.00         1
#                    Coronary & Renal Denervation>Interventional Coronary>Guidewires>Abbott Laboratories>Hi-Torque Progress       1.00      1.00      1.00         1
#                                   Coronary & Renal Denervation>Interventional Coronary>Guidewires>Abbott Laboratories>nan       1.00      1.00      1.00         2
#                                          Coronary & Renal Denervation>Interventional Coronary>Guidewires>Asahi Intecc>nan       1.00      1.00      1.00         1
#                                     Coronary & Renal Denervation>Interventional Coronary>Guidewires>Boston Scientific>nan       0.80      1.00      0.89         4
#                                             Coronary & Renal Denervation>Interventional Coronary>Guidewires>Teleflex>R350       0.00      0.00      0.00         1
#                                                Coronary & Renal Denervation>Interventional Coronary>Guidewires>Terumo>nan       0.50      1.00      0.67         2
#                                                   Coronary & Renal Denervation>Interventional Coronary>Guidewires>nan>nan       0.00      0.00      0.00         1
#                              Coronary & Renal Denervation>Interventional Coronary>Guiding Catheters>Boston Scientific>nan       1.00      1.00      1.00         1
#                                         Coronary & Renal Denervation>Interventional Coronary>Guiding Catheters>Terumo>nan       0.00      0.00      0.00         1
#                                     Coronary & Renal Denervation>Interventional Coronary>Guiding Catheters>Wellinq>Primum       0.00      0.00      0.00         1
#                              Coronary & Renal Denervation>Interventional Coronary>Inflation Devices>Boston Scientific>nan       0.90      1.00      0.95         9
#                                      Coronary & Renal Denervation>Interventional Coronary>Inflation Devices>Vygon>Dolphin       0.00      0.00      0.00         1
#                                Coronary & Renal Denervation>Interventional Coronary>PTCA Balloons>Abbott Laboratories>nan       0.00      0.00      0.00         0
#                               Coronary & Renal Denervation>Interventional Coronary>PTCA Balloons>Boston Scientific>Emerge       1.00      1.00      1.00         2
#                                Coronary & Renal Denervation>Interventional Coronary>PTCA Balloons>Meril Life Sciences>nan       0.33      1.00      0.50         1
#                                            Coronary & Renal Denervation>Interventional Coronary>PTCA Balloons>Rontis>Inro       0.00      0.00      0.00         1
#                                   Coronary & Renal Denervation>Interventional Coronary>PTCA Balloons>Translumina>Cathy N4       0.00      0.00      0.00         0
#                                                             Cranial & Spinal Technologies>Biologics>DBM>Medtronic>Grafton       1.00      1.00      1.00         1
#                                                    Cranial & Spinal Technologies>Biologics>Synthetics>Cerapedics>i-Factor       1.00      1.00      1.00         2
#                                                         Cranial & Spinal Technologies>Biologics>Synthetics>Exabone>HA/TCP       1.00      1.00      1.00         1
#                                                         Cranial & Spinal Technologies>Biologics>Synthetics>Novabone>putty       0.00      0.00      0.00         1
#                                               Cranial & Spinal Technologies>Biologics>Synthetics>Zimmer Biomet>Regeneross       0.33      1.00      0.50         1
#                                                 Cranial & Spinal Technologies>Biologics>Synthetics>Zimmer Biomet>ingenios       0.00      0.00      0.00         2
#                                                           Cranial & Spinal Technologies>Biologics>Synthetics>other>others       1.00      1.00      1.00         1
#                                                          Cranial & Spinal Technologies>Biologics>Synthetics>others>others       1.00      1.00      1.00         3
#                                  Cranial & Spinal Technologies>CSF>Cranial Access and Repair>Integra Lifesciences>DuraGen       0.00      0.00      0.00         0
#                                            Cranial & Spinal Technologies>CSF>Cranial Access and Repair>Stryker>Duramatrix       0.00      0.00      0.00         1
#                                               Cranial & Spinal Technologies>CSF>Hydrocephalus>Integra Lifesciences>Pudenz       1.00      1.00      1.00         1
#                                               Cranial & Spinal Technologies>Core Spine>Accessory Devices>Clariance>others       1.00      1.00      1.00         1
#                                                      Cranial & Spinal Technologies>Core Spine>Corpectomy>Medtronic>others       1.00      1.00      1.00         1
#                                  Cranial & Spinal Technologies>Core Spine>Interbody Device - Cervical>Spineway>Ayers Rock       0.00      0.00      0.00         0
#                                       Cranial & Spinal Technologies>Core Spine>Interbody Device - Cervical>Stryker>Reflex       1.00      1.00      1.00         1
#                                         Cranial & Spinal Technologies>Core Spine>Interbody Device - Cervical>ZimVie>ROI-C       0.33      1.00      0.50         1
#                                  Cranial & Spinal Technologies>Core Spine>Interbody Device - Cervical>Zimmer Biomet>ROI-C       0.00      0.00      0.00         2
#                                        Cranial & Spinal Technologies>Core Spine>Interbody Device - Cervical>others>others       1.00      1.00      1.00         1
#                        Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>Globus Medical>Coalition       1.00      1.00      1.00         1
#                               Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>Human Tech>Adonis       1.00      1.00      1.00         1
#                              Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>Seaspine>Shoreline       1.00      1.00      1.00         3
#                                 Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>Seaspine>others       0.50      1.00      0.67         1
#                             Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>Spineway>Twin Peaks       1.00      1.00      1.00         7
#                                   Cranial & Spinal Technologies>Core Spine>Interbody Device - Thoracolumbar>others>others       1.00      1.00      1.00         1
#                                                          Cranial & Spinal Technologies>Core Spine>Spacer>Globus>Coalition       1.00      1.00      1.00         1
#                                Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Cervical>Human Tech>Hero       0.50      1.00      0.67         1
#                                Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Cervical>Human Tech>hero       0.00      0.00      0.00         1
#                               Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Cervical>Medtronic>others       1.00      1.00      1.00         1
#                             Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Cervical>Seaspine>Shoreline       1.00      1.00      1.00         2
#                                  Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Cervical>others>others       1.00      0.50      0.67         2
#                                Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>J&J>others       1.00      1.00      1.00        10
#                           Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Nuvasive>Reline       1.00      1.00      1.00         2
#                           Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Seaspine>Malibu       1.00      1.00      1.00         4
#                         Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Seaspine>New Port       1.00      1.00      1.00         3
#                           Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Seaspine>malibu       1.00      1.00      1.00         2
#                           Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Seaspine>others       0.00      0.00      0.00         1
#                     Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation - Thoracolumbar>Total Life>Centerline       0.00      0.00      0.00         1
#                                          Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation >ARTHREX>ARTHREX       1.00      1.00      1.00         1
#                                            Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation >others>others       1.00      1.00      1.00         1
#                                          Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation>Medtronic>others       1.00      1.00      1.00         3
#                                         Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation>Orthofix>Gotfried       1.00      1.00      1.00         1
#                                          Cranial & Spinal Technologies>Core Spine>Spinal Fusion Fixation>Spineart>Scarlet       1.00      1.00      1.00         1
#                                                               Cranial & Spinal Technologies>Core Spine>nan>Arthrex>others       1.00      1.00      1.00         1
#                               Cranial & Spinal Technologies>Former Neurosurgery>Core Navigation - Disposable>Brainlab>nan       1.00      1.00      1.00         1
#                 Cranial & Spinal Technologies>Former Neurosurgery>Nerve Monitoring Devices - Disposable>Natus Medical>nan       0.00      0.00      0.00         1
#     Cranial & Spinal Technologies>Former Neurosurgery>Powered Surgical Instruments - Capital>Adeor Medical>Velocity Alpha       0.00      0.00      0.00         1
#                     Cranial & Spinal Technologies>Former Neurosurgery>Powered Surgical Instruments - Capital>B. Braun>nan       0.00      0.00      0.00         0
#  Cranial & Spinal Technologies>Former Neurosurgery>Powered Surgical Instruments - Disposable>Adeor Medical>Velocity Alpha       0.00      0.00      0.00         0
#                  Cranial & Spinal Technologies>Former Neurosurgery>Powered Surgical Instruments - Disposable>B. Braun>nan       0.60      0.75      0.67         4
#            Cranial & Spinal Technologies>Former Neurosurgery>Powered Surgical Instruments - Disposable>Nakanishi>Primado2       1.00      1.00      1.00         1
#                                               Diabetes>MDI CGM Standalone>CGM Sensors>Abbott Laboratories>Freestyle Libre       1.00      0.50      0.67         2
#                                                                  Diabetes>MDI CGM Standalone>CGM Sensors>Medtronic>Enlite       0.75      1.00      0.86         3
#                                                               Diabetes>Pump>Pump Consumables>Medtronic>Medtronic - Others       1.00      1.00      1.00         1
#                                                                 Diabetes>Pump>Pump Consumables>Medtronic>Minimed Paradigm       1.00      0.75      0.86         4
#                                                                                     Diabetes>Pump>Pumps>Medtronic>Minimed       0.00      0.00      0.00         0
#                                                                                Diabetes>Pump>Pumps>Medtronic>Minimed 640G       1.00      0.67      0.80         3
#                                                                        ENT>ENT>Core Navigation - Disposable>Medtronic>nan       1.00      1.00      1.00         1
#                                                                             ENT>ENT>ENT Drills - Disposable>Medtronic>nan       1.00      1.00      1.00         2
#                                                                             ENT>ENT>ENT Drills - Disposable>others>others       0.00      0.00      0.00         1
#                                                     ENT>ENT>ENT Microdebriders - Capital Equipment>Smith & Nephew>Patinum       0.00      0.00      0.00         2
#                                                                      ENT>ENT>Eustachian Tube Dilation>Spiggle & Theis>nan       1.00      1.00      1.00         1
#                                                                       ENT>ENT>Nasal Packing/Splints>Smith & Nephew>canula       0.00      0.00      0.00         0
#                                                   ENT>ENT>Otology - Middle Ear Implants>ADVANCED BIONICS>ADVANCED BIONICS       0.00      0.00      0.00         2
#                                     ENT>ENT>Otology - Middle Ear Implants>Kurz Medical>Kurz Medical - Middle Ear Implants       0.00      0.00      0.00         2
#                                                               ENT>ENT>Otology - Ventilation Tubes>Invotec>Shepard Grommet       0.00      0.00      0.00         1
#                                   Extracorporeal Therapies>Extracorporeal Therapies>Cardiopulmonary/Oxygenators>Nipro>nan       0.00      0.00      0.00         1
#                                                                      Implantables>Implantables>ICD>Biotronik>Intica Neo 5       0.00      0.00      0.00         1
#                                                                   Implantables>Implantables>ICD>Boston Scientific>Dynagen       0.67      1.00      0.80         2
#                                                           Implantables>Implantables>Pacemaker>Abbott Laboratories>Microny       0.00      0.00      0.00         1
#                                                                     Implantables>Implantables>Pacemaker>Biotronik>Edora 8       0.00      0.00      0.00         1
#                                                                     Implantables>Implantables>Pacemaker>Biotronik>Enticos       0.00      0.00      0.00         0
#                                                                Implantables>Implantables>Pacemaker>Biotronik>Enticos 4 SR       0.33      1.00      0.50         1
#                                                           Implantables>Implantables>Pacemaker>Boston Scientific>Proponent       0.00      0.00      0.00         2
#                                                                                        Implantables>nan>nan>Re-export>nan       0.00      0.00      0.00         1
#                                               Neuromodulation>Brain Modulation>DBS - Extensions>Boston Scientific>Vercise       0.00      0.00      0.00         1
#                                                    Neuromodulation>Brain Modulation>DBS - Leads>Boston Scientific>Vercise       0.00      0.00      0.00         0
#                             Neuromodulation>Brain Modulation>DBS- Neurostimulator (Rechargable)>Boston Scientific>Vercise       0.00      0.00      0.00         1
#                                                                     Neuromodulation>Brain Modulation>nan>Medtronic>Activa       0.00      0.00      0.00         1
#                                                                  Neuromodulation>Pain>Bone Cement>Biopsybell>Renova Spine       1.00      1.00      1.00         1
#                                                                               Neuromodulation>Pain>Bone Cement>Tecres>nan       1.00      1.00      1.00         1
#                                                        Neuromodulation>Pain>Delivery system and accessories>Medtronic>nan       1.00      1.00      1.00         3
#                                                  Neuromodulation>Pain>Delivery system and accessories>Seawon Meditech>nan       1.00      1.00      1.00         2
#                                                          Neuromodulation>Pain>Delivery system and accessories>Stryker>nan       0.00      0.00      0.00         2
#                                                    Neurovascular>Neurovascular>Accessories - Microcatheter>Terumo>Headway       1.00      1.00      1.00         2
#                                                        Neurovascular>Neurovascular>Accessories - catheter>Penumbra>others       1.00      1.00      1.00         2
#                                                          Neurovascular>Neurovascular>Accessories - catheter>Terumo>others       1.00      1.00      1.00         1
#                                                    Neurovascular>Neurovascular>Accessories - microcatheter>Terumo>headway       1.00      1.00      1.00         1
#                                                    Neurovascular>Neurovascular>Accessories - microcatheter>terumo>Headway       1.00      1.00      1.00         3
#                                      Neurovascular>Neurovascular>Accessory Devices>Balt Extrusion>Balt Extrusion - Others       0.00      0.00      0.00         0
#                                                    Neurovascular>Neurovascular>Accessory Devices>Stryker>Stryker - Others       0.00      0.00      0.00         1
#                                                               Neurovascular>Neurovascular>Accessory Devices>others>others       0.00      0.00      0.00         0
#                                                        Neurovascular>Neurovascular>Flow Diverter>Balt Extrusion>Silk Plus       0.00      0.00      0.00         1
#                                                                     Neurovascular>Neurovascular>Flow Diverter>Terumo>Eric       1.00      1.00      1.00         1
#                                                                     Neurovascular>Neurovascular>Flow Diverter>Terumo>Fred       0.50      0.50      0.50         2
#                                                                   Neurovascular>Neurovascular>Flow Diverter>others>others       0.00      0.00      0.00         1
#                                                                   Neurovascular>Neurovascular>Guidewires>Medtronic>Mirage       1.00      1.00      1.00         1
#                                                         Neurovascular>Neurovascular>Guiding Catheter>BALT Extrusion>Fargo       0.00      0.00      0.00         1
#                                                          Neurovascular>Neurovascular>Guiding Catheter>Penumbra>Neuron Max       0.00      0.00      0.00         2
#                                                         Neurovascular>Neurovascular>INR Embolization Coil>Medtronic>Axium       1.00      1.00      1.00         3
#                                                     Neurovascular>Neurovascular>INR Embolization Coil>Penumbra>Smart Coil       0.00      0.00      0.00         2
#                                                      Neurovascular>Neurovascular>INR Embolization Coil>Penumbra>Smartcoil       0.00      0.00      0.00         1
#                                                         Neurovascular>Neurovascular>INR Embolization Coil>Penumbra>others       1.00      1.00      1.00         1
#                                                        Neurovascular>Neurovascular>INR Embolization Coil>Terumo>Hydrosoft       1.00      1.00      1.00         2
#                                                        Neurovascular>Neurovascular>INR Embolization Coil>Terumo>Hypersoft       0.00      0.00      0.00         0
#                                                        Neurovascular>Neurovascular>INR Embolization Coil>Terumo>Microplex       0.98      0.98      0.98        53
#                                                                Neurovascular>Neurovascular>Intracranial Stent>Terumo>Lvis       1.00      1.00      1.00        13
#                                                                Neurovascular>Neurovascular>Intracranial Stent>Terumo>lvis       1.00      1.00      1.00         1
#                                                               Neurovascular>Neurovascular>Microcatheters>Medtronic>Apollo       1.00      1.00      1.00         4
#                                                              Neurovascular>Neurovascular>Microcatheters>Medtronic>Echelon       1.00      1.00      1.00         1
#                                                               Neurovascular>Neurovascular>Microcatheters>Medtronic>Navien       1.00      1.00      1.00         4
#                                                             Neurovascular>Neurovascular>Microcatheters>Medtronic>Rebar 18       0.83      1.00      0.91         5
#                                                             Neurovascular>Neurovascular>Microcatheters>Medtronic>Rebar 27       0.00      0.00      0.00         1
#                                                               Neurovascular>Neurovascular>Microcatheters>Penumbra>PX SLIM       1.00      1.00      1.00         1
#                                                                   Neurovascular>Neurovascular>Microcatheters>Terumo>Sofia       0.00      0.00      0.00         0
#                                                           Neurovascular>Neurovascular>Reperfusion Catheter>Penumbra>Jet 7       1.00      1.00      1.00         1
#                                                             Neurovascular>Neurovascular>Reperfusion Catheter>Penumbra>MAX       0.00      0.00      0.00         0
#                                                        Neurovascular>Neurovascular>Reperfusion Catheter>Terumo>Sofia Plus       0.00      0.00      0.00         1
#                                                             Neurovascular>Neurovascular>Reperfusion Catheter>terumo>Sofia       1.00      1.00      1.00        12
#                                                 Patient Monitoring>Cerebral Compromise>Sensors, LOC>GE Healthcare>Entropy       0.00      0.00      0.00         3
#                                                   Patient Monitoring>Respiratory Compromise>Capnography Lines>Westmed>nan       1.00      1.00      1.00         1
#                                           Patient Monitoring>Respiratory Compromise>Monitors - Pulse Oximeter>nan>Low ASP       1.00      1.00      1.00         1
#                                         Patient Monitoring>Respiratory Compromise>Monitors, Pulse Oximetry>Masimo>Bedside       1.00      1.00      1.00         1
#                                               Patient Monitoring>Respiratory Compromise>Sensors, Disposable>Medtronic>nan       1.00      0.89      0.94         9
#                                                 Patient Monitoring>Respiratory Compromise>Sensors, Disposable>Mindray>nan       1.00      1.00      1.00         1
#                                                     Patient Monitoring>Respiratory Compromise>Sensors, Disposable>nan>nan       0.25      1.00      0.40         1
#                            Patient Monitoring>Respiratory Compromise>Sensors, Reusable>Medical Accessories and Cables>nan       0.00      0.00      0.00         1
#                                                 Peripheral & Endovenous>Endovenous (Inc. Embolization)>Coil>Terumo>Others       0.00      0.00      0.00         1
#                                 Peripheral & Endovenous>Endovenous (Inc. Embolization)>Detachable Coil>Medtronic>Concerto       1.00      1.00      1.00         4
#                                        Peripheral & Endovenous>Endovenous (Inc. Embolization)>Detachable Coil>Terumo>Azur       1.00      1.00      1.00         1
#                                              Peripheral & Endovenous>Endovenous (Inc. Embolization)>PV Plug>Others>Others       0.00      0.00      0.00         0
#                                   Peripheral & Endovenous>Endovenous (Inc. Embolization)>Pushable Coil>Cook Medical>Hilal       1.00      1.00      1.00         1
#                                              Peripheral & Endovenous>Endovenous (Inc. Embolization)>Pushable Coil>nan>nan       0.00      0.00      0.00         0
#                                Peripheral & Endovenous>Peripheral Vascular / Coronary>Drug Coated Balloon (assume)>BD>nan       1.00      0.50      0.67         2
#                             Peripheral & Endovenous>Peripheral Vascular / Coronary>PTA / PTCA Balloons / Catheters>BD>nan       0.00      0.00      0.00         0
#              Peripheral & Endovenous>Peripheral Vascular / Coronary>PTA / PTCA Balloons / Catheters>Boston Scientific>nan       1.00      1.00      1.00         1
#                      Peripheral & Endovenous>Peripheral Vascular / Coronary>PTA / PTCA Balloons / Catheters>Medtronic>nan       1.00      1.00      1.00         8
#                         Peripheral & Endovenous>Peripheral Vascular / Coronary>PTA / PTCA Balloons / Catheters>Terumo>nan       1.00      1.00      1.00         1
#                                              Peripheral & Endovenous>Peripheral Vascular / Coronary>Sheaths>Terumo>Others       1.00      0.50      0.67         2
#                                                 Peripheral & Endovenous>Peripheral Vascular / Coronary>Sheaths>Terumo>nan       1.00      1.00      1.00         2
#                                             Peripheral & Endovenous>Peripheral Vascular>Atherectomy>Boston Scientific>nan       0.83      1.00      0.91         5
#                                                   Peripheral & Endovenous>Peripheral Vascular>Atherectomy>Philips>Phoenix       0.00      0.00      0.00         1
#                                Peripheral & Endovenous>Peripheral Vascular>BMS BX Stent>Abbott Laboratories>Omnlink Elite       0.00      0.00      0.00         0
#                                              Peripheral & Endovenous>Peripheral Vascular>BMS SX Stent>Biotronik>Pulsar 18       0.00      0.00      0.00         0
#                                              Peripheral & Endovenous>Peripheral Vascular>BMS SX Stent>Biotronik>Pulsar 35       0.00      0.00      0.00         1
#                                            Peripheral & Endovenous>Peripheral Vascular>BMS SX Stent>Medtronic>Protege Gps       1.00      1.00      1.00         1
#                                    Peripheral & Endovenous>Peripheral Vascular>BMS Stent>Abbott Laboratories>Absolute Pro       1.00      1.00      1.00         1
#                                                             Peripheral & Endovenous>Peripheral Vascular>BMS Stent>nan>nan       1.00      1.00      1.00         1
#                              Peripheral & Endovenous>Peripheral Vascular>Carotid SX Stent>Abbott Laboratories>Rx Acculink       0.00      0.00      0.00         1
#                                      Peripheral & Endovenous>Peripheral Vascular>Carotid SX Stent>Abbott Laboratories>nan       0.00      0.00      0.00         1
#                                            Peripheral & Endovenous>Peripheral Vascular>Carotid SX Stent>InsipireMD>CGuard       1.00      1.00      1.00         1
#                                                      Peripheral & Endovenous>Peripheral Vascular>Carotid SX Stent>nan>nan       0.00      0.00      0.00         0
#                                       Peripheral & Endovenous>Peripheral Vascular>Guidewires>Abbott Laboratories>Hitorque       1.00      1.00      1.00         1
#                                                   Peripheral & Endovenous>Peripheral Vascular>Guidewires>Medtronic>Nitrex       1.00      1.00      1.00         3
#                              Peripheral & Endovenous>Peripheral Vascular>Standard PTA Balloons>Abbott Laboratories>Armada       0.33      1.00      0.50         1
#                             Peripheral & Endovenous>Peripheral Vascular>Standard PTA Balloons>Abbott Laboratories>Viatrac       0.00      0.00      0.00         0
#                               Peripheral & Endovenous>Peripheral Vascular>Standard PTA Balloons>Medtronic>Nanocross Elite       1.00      1.00      1.00         3
#                                    Peripheral & Endovenous>Peripheral Vascular>Standard PTA Balloons>iVascular>Oceanus 14       0.00      0.00      0.00         2
#                                    Peripheral & Endovenous>Peripheral Vascular>Standard PTA Balloons>iVascular>Oceanus 35       0.00      0.00      0.00         1
#                                Renal Care Solutions>Acute Therapies>Acute Consumables & Dialyzers>Fresenius>Multifiltrate       1.00      1.00      1.00         1
#                                               Renal Care Solutions>Acute Therapies>Acute Machines>Fresenius>Multifiltrate       0.00      0.00      0.00         0
#                                   Renal Care Solutions>Chronic Bellco & Tech Services>Chronic Consumables>Baxter>Novaline       0.00      0.00      0.00         1
#                     Renal Care Solutions>Chronic Bellco & Tech Services>Chronic Consumables>Fresenius Medical Care>AV-Set       0.00      0.00      0.00         0
#                                  Renal Care Solutions>Chronic Bellco & Tech Services>Chronic Consumables>Medtronic>Others       1.00      1.00      1.00         2
#                                      Renal Care Solutions>Chronic Bellco & Tech Services>Chronic Dialyzers>Baxter>Phoenix       0.00      0.00      0.00         0
#                                       Renal Care Solutions>Chronic Bellco & Tech Services>Chronic Machines>Fresenius>4008       0.00      0.00      0.00         1
#                                                       Renal Care Solutions>Renal Access>Acute Renal Access>BD>Bd - Others       0.67      1.00      0.80         2
#                                                           Renal Care Solutions>Renal Access>Acute Renal Access>BD>Niagara       0.00      0.00      0.00         1
#                                                        Renal Care Solutions>Renal Access>Acute Renal Access>Others>Others       0.00      0.00      0.00         0
#                                                      Renal Care Solutions>Renal Access>Chronic Renal Access>others>others       0.00      0.00      0.00         1
#                                                     Renal Care Solutions>Renal Access>Fistula/Cannula>B. Braun>Diacan Pro       1.00      1.00      1.00         1
#                                                           Renal Care Solutions>Renal Access>Fistula/Cannula>others>others       1.00      1.00      1.00         1
#                                                                                   Renal Care Solutions>nan>nan>BD>Niagara       1.00      0.33      0.50         3
#                     Respiratory Intervention>Adjunctive Therapies>Active Humidification - Consumables>Fisher & Paykel>nan       0.00      0.00      0.00         1
#                                 Respiratory Intervention>Adjunctive Therapies>Active Humidification - Consumables>nan>nan       0.00      0.00      0.00         0
#                                             Respiratory Intervention>Adjunctive Therapies>HFO2T - Consumables>Westmed>nan       0.00      0.00      0.00         0
#                                       Respiratory Intervention>Airway Management>Endotracheal Tubes>Boston Scientific>nan       1.00      1.00      1.00         2
#                                             Respiratory Intervention>Airway Management>Endotracheal Tubes>ICU Medical>nan       0.00      0.00      0.00         1
#                                                 Respiratory Intervention>Airway Management>Endotracheal Tubes>Medline>nan       1.00      1.00      1.00         1
#                                               Respiratory Intervention>Airway Management>Endotracheal Tubes>Medtronic>nan       0.86      0.86      0.86         7
#                                                     Respiratory Intervention>Airway Management>Endotracheal Tubes>nan>nan       0.92      0.92      0.92        13
#                                                     Respiratory Intervention>Airway Management>Laryngeal Mask>Medline>nan       0.00      0.00      0.00         1
#                                                    Respiratory Intervention>Airway Management>Laryngeal Mask>Teleflex>nan       0.00      0.00      0.00         0
#                 Respiratory Intervention>Airway Management>Nasopharyngeal and Oropharyngeal Airways>Boston Scientific>nan       1.00      1.00      1.00         1
#                          Respiratory Intervention>Airway Management>Nasopharyngeal and Oropharyngeal Airways>Teleflex>nan       1.00      1.00      1.00         1
#                                                     Respiratory Intervention>Airway Management>Tracheostomy>Medtronic>nan       0.00      0.00      0.00         1
#                                                    Respiratory Intervention>Airway Management>Tracheostomy>Sonomedics>nan       1.00      0.50      0.67         2
#                                                           Respiratory Intervention>Airway Management>Tracheostomy>nan>nan       0.75      1.00      0.86         6
#    Respiratory Intervention>Breathing Systems>Breathing Circuits>Ambu>Bundled devices, change ASP and value but not units       1.00      1.00      1.00         1
#                                                 Respiratory Intervention>Breathing Systems>Breathing Circuits>Draeger>nan       1.00      1.00      1.00         1
#                                         Respiratory Intervention>Breathing Systems>Breathing Circuits>Fisher & Paykel>nan       0.00      0.00      0.00         1
#                                                Respiratory Intervention>Breathing Systems>Breathing Circuits>Hamilton>nan       1.00      1.00      1.00         1
#                                             Respiratory Intervention>Breathing Systems>Breathing Circuits>ICU Medical>nan       0.00      0.00      0.00         1
#                                                Respiratory Intervention>Breathing Systems>Breathing Circuits>Teleflex>nan       1.00      0.67      0.80         3
#                                                 Respiratory Intervention>Breathing Systems>Breathing Circuits>Westmed>nan       1.00      1.00      1.00         2
#                                                     Respiratory Intervention>Breathing Systems>Breathing Circuits>nan>nan       0.00      0.00      0.00         0
#                                                            Respiratory Intervention>Breathing Systems>Filters>Westmed>HME       0.00      0.00      0.00         1
#                                                                Respiratory Intervention>Breathing Systems>Filters>nan>nan       0.00      0.00      0.00         1
#                                                   Respiratory Intervention>Ventilation>Ventilator Consumables>Draeger>nan       1.00      1.00      1.00         3
#                                           Respiratory Intervention>Ventilation>Ventilator Consumables>Fisher & Paykel>nan       1.00      1.00      1.00         1
#                                                    Respiratory Intervention>Ventilation>Ventilator Consumables>Sunmed>nan       1.00      1.00      1.00         1
#                                                    Respiratory Intervention>Ventilation>Ventilator Consumables>Vyaire>nan       1.00      1.00      1.00         1
#                                                       Respiratory Intervention>Ventilation>Ventilator Consumables>nan>nan       1.00      0.33      0.50         3
#                   Respiratory Intervention>Ventilation>Ventilator Consumables_Temporary Imports>Ascotech_NA_Important>nan       0.00      0.00      0.00         1
#                     Respiratory Intervention>Ventilation>Ventilator Consumables_Temporary Imports>Ivemsa_Manufacturer>nan       1.00      1.00      1.00         2
#                                  Respiratory Intervention>Ventilation>Ventilator Consumables_Temporary Imports>Vyaire>nan       0.00      0.00      0.00         0
#                                     Respiratory Intervention>Ventilation>Ventilator Consumables_Temporary Imports>nan>nan       0.00      0.00      0.00         1
#                                                 Respiratory Interventions>Airway Management>Endotracheal Tubes>Amsino>nan       1.00      1.00      1.00         1
#                                              Respiratory Interventions>Airway Management>Endotracheal Tubes>Medtronic>nan       1.00      1.00      1.00         3
#                                                Respiratory Interventions>Breathing Systems>Breathing Circuits>Draeger>nan       1.00      1.00      1.00         2
#                                   Structural Heart & Aortic>Aortic>Abdominal Stent Graft (Bifurcated)>W. L. Gore>Excluder       0.00      0.00      0.00         0
#                                               Structural Heart & Aortic>Aortic>Abdominal Stent Graft (Bifurcated)>nan>nan       1.00      1.00      1.00         1
# ...
#                                                    Surgical Innovations>Surgical Instrumentation & Access>Trocars>J&J>nan       1.00      1.00      1.00         2
#                                              Surgical Innovations>Surgical Instrumentation & Access>Trocars>Medtronic>nan       0.00      0.00      0.00         1
#                                              Surgical Innovations>Surgical Instrumentation & Access>Trocars>Others>Others       0.88      1.00      0.94        36
#                                   Surgical Innovations>Surgical Instrumentation & Access>Trocars>Purple Surgical>Ultimate       0.75      1.00      0.86         6
#                                        Surgical Innovations>Surgical Instrumentation & Access>Trocars>Purple Surgical>nan       0.00      0.00      0.00         2
#                                     Surgical Innovations>Surgical Instrumentation & Access>Wound Retractors>Others>Others       1.00      1.00      1.00         1
#                                                Surgical Innovations>Sutures>Barbed Suture|Absorbable>Assut Europe>Filbloc       1.00      1.00      1.00         1
#                                                     Surgical Innovations>Sutures>Barbed Suture|Absorbable>Medtronic>V-Loc       1.00      0.67      0.80         3
#                                                  Surgical Innovations>Sutures>Barbed Suture|Absorbable>Medtronic>V-Loc 90       0.00      0.00      0.00         1
#                                          Surgical Innovations>Sutures>Barbed Suture|Absorbable>Medtronic>medtronic-others       0.00      0.00      0.00         1
#                                                Surgical Innovations>Sutures>Barbed Suture|Non-Absorbable>J&J>J&J - Others       1.00      0.50      0.67         2
#                                                   Surgical Innovations>Sutures>Barbed Suture|Non-Absorbable>J&J>Stratafix       0.00      0.00      0.00         1
#                                                 Surgical Innovations>Sutures>Barbed Suture|Non-Absorbable>Medtronic>V-Loc       1.00      1.00      1.00         1
#                                             Surgical Innovations>Sutures>Barbed Suture|Non-Absorbable>Medtronic>V-Loc Pbt       0.33      1.00      0.50         1
#                               Surgical Innovations>Sutures>Conventional Suture|Absorbable Antibacterial>J&J>Monocryl Plus       1.00      0.67      0.80         3
#                                    Surgical Innovations>Sutures>Conventional Suture|Absorbable Antibacterial>J&J>Pds Plus       1.00      1.00      1.00         3
#                                      Surgical Innovations>Total Stapling>Open - Stapling Device>Meril Life Sciences>Mirus       1.00      1.00      1.00         1
#                                                  Surgical Innovations>Total Stapling>Open - Stapling Device>Others>Others       0.77      0.88      0.82        26
#                                        Surgical Innovations>Total Stapling>Open - Stapling Device>Waston medical>III ROWS       1.00      1.00      1.00         1
#                                                  Surgical Innovations>Total Stapling>Open - Stapling Device>others>others       0.60      0.50      0.55         6
#                                                           Surgical Innovations>Total stapling>Open - Reload>Others>Others       1.00      1.00      1.00         1
#                                   Surgical Innovations>Total stapling>Open - Stapling Device>Medtronic>Medtronic - Others       1.00      1.00      1.00         1
#                                                  Surgical Innovations>Total stapling>Open - Stapling Device>Others>Others       1.00      1.00      1.00         1
#                                                        neurovascular>neurovascular>INR Embolization Coil>Terumo>Microplex       1.00      1.00      1.00         1
#
#                                                                                                                  accuracy                           0.83      1789
#                                                                                                                 macro avg       0.60      0.60      0.59      1789
#                                                                                                              weighted avg       0.81      0.83      0.81      1789
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\AbhishekSrivastava\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

def multioutput_accuracy(y_true, y_pred):
    # Convert to numpy arrays if they are pandas DataFrames
    if isinstance(y_true, pd.DataFrame):
        y_true = y_true.to_numpy()
    if isinstance(y_pred, pd.DataFrame):
        y_pred = y_pred.to_numpy()

    accuracies = [accuracy_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])]
    return np.mean(accuracies)

custom_scorer = make_scorer(multioutput_accuracy)


# Perform cross-validation using the custom scorer
scores = cross_val_score(model, mapping_lens[features], mapping_lens[targets], cv=5, scoring=custom_scorer)

print("Cross-validation scores:", scores)
print("Average cross-validation score:", scores.mean())
# Out:
# Cross-validation scores: [0.49982609 0.72508711 0.57456446 0.7815331  0.21393728]
# Average cross-validation score: 0.5589896076352068

# %%
## Lets add SMOTE
## If your dataset has imbalanced classes, consider applying techniques 
# like SMOTE for oversampling the minority class or adjusting 
## class weights in the model.

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\abhisheksrivastava\anaconda3\lib\site-packages (from imbalanced-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\abhisheksrivastava\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\abhisheksrivastava\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Collecting joblib>=1.1.1 (from imbalanced-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abhisheksrivastava\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#    --------------------------------------- 257.7/257.7 kB 16.5 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 302.2/302.2 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: joblib, imbalanced-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
# Successfully installed imbalanced-learn-0.12.0 joblib-1.3.2

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# %%
# Define the model pipeline with SMOTE
model_with_smote = ImbPipeline(steps=[
    ('preprocessor', preprocessor),
    ('smote', SMOTE(random_state=33)),  # Apply SMOTE
    ('classifier', RandomForestClassifier())
])

# Split data
X_train, X_test, y_train, y_test = train_test_split(mapping_lens[features], mapping_lens[target], test_size=0.2, random_state=33)

# Train the model with SMOTE applied to the training data
model_with_smote.fit(X_train, y_train)

# Predict
y_pred = model_with_smote.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 12>()
#       9 X_train, X_test, y_train, y_test = train_test_split(mapping_lens[features], mapping_lens[target], test_size=0.2, random_state=33)
#      11 # Train the model with SMOTE applied to the training data
# ---> 12 model_with_smote.fit(X_train, y_train)
#      14 # Predict
#      15 y_pred = model_with_smote.predict(X_test)
#
# File ~\Anaconda3\lib\site-packages\imblearn\utils\fixes.py:85, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#      78     estimator._validate_params()
#      80 with config_context(
#      81     skip_parameter_validation=(
#      82         prefer_skip_nested_validation or global_skip_validation
#      83     )
#      84 ):
# ---> 85     return fit_method(estimator, *args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\imblearn\pipeline.py:322, in Pipeline.fit(self, X, y, **params)
#     278 """Fit the model.
#     279
#     280 Fit all the transforms/samplers one after the other and
#    (...)
#     319     This estimator.
#     320 """
#     321 routed_params = self._check_method_params(method="fit", props=params)
# --> 322 Xt, yt = self._fit(X, y, routed_params)
#     323 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     324     if self._final_estimator != "passthrough":
#
# File ~\Anaconda3\lib\site-packages\imblearn\pipeline.py:258, in Pipeline._fit(self, X, y, routed_params)
#     248     X, fitted_transformer = fit_transform_one_cached(
#     249         cloned_transformer,
#     250         X,
#    (...)
#     255         params=routed_params[name],
#     256     )
#     257 elif hasattr(cloned_transformer, "fit_resample"):
# --> 258     X, y, fitted_transformer = fit_resample_one_cached(
#     259         cloned_transformer,
#     260         X,
#     261         y,
#     262         message_clsname="Pipeline",
#     263         message=self._log_message(step_idx),
#     264         params=routed_params[name],
#     265     )
#     266 # Replace the transformer of the step with the fitted
#     267 # transformer. This is necessary when loading the transformer
#     268 # from the cache.
#     269 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\Anaconda3\lib\site-packages\joblib\memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File ~\Anaconda3\lib\site-packages\imblearn\pipeline.py:1050, in _fit_resample_one(sampler, X, y, message_clsname, message, params)
#    1048 def _fit_resample_one(sampler, X, y, message_clsname="", message=None, params=None):
#    1049     with _print_elapsed_time(message_clsname, message):
# -> 1050         X_res, y_res = sampler.fit_resample(X, y, **params.get("fit_resample", {}))
#    1052         return X_res, y_res, sampler
#
# File ~\Anaconda3\lib\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File ~\Anaconda3\lib\site-packages\imblearn\base.py:112, in SamplerMixin.fit_resample(self, X, y)
#     106 X, y, binarize_y = self._check_X_y(X, y)
#     108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
# --> 112 output = self._fit_resample(X, y)
#     114 y_ = (
#     115     label_binarize(output[1], classes=np.unique(y)) if binarize_y else output[1]
#     116 )
#     118 X_, y_ = arrays_transformer.transform(output[0], y_)
#
# File ~\Anaconda3\lib\site-packages\imblearn\over_sampling\_smote\base.py:382, in SMOTE._fit_resample(self, X, y)
#     379 X_class = _safe_indexing(X, target_class_indices)
#     381 self.nn_k_.fit(X_class)
# --> 382 nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     383 X_new, y_new = self._make_samples(
#     384     X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#     385 )
#     386 X_resampled.append(X_new)
#
# File ~\Anaconda3\lib\site-packages\sklearn\neighbors\_base.py:727, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     725 n_samples_fit = self.n_samples_fit_
#     726 if n_neighbors > n_samples_fit:
# --> 727     raise ValueError(
#     728         "Expected n_neighbors <= n_samples, "
#     729         " but n_samples = %d, n_neighbors = %d" % (n_samples_fit, n_neighbors)
#     730     )
#     732 n_jobs = effective_n_jobs(self.n_jobs)
#     733 chunked_results = None
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 6
